# %%
# %load_ext sql

# %%
# %sql sqlite:///proyecto1.db
# Out:
# u'Connected: @proyecto1.db'

# %%
# %sql PRAGMA table_info(ontime)
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(0, u'Year', u'INT', 0, None, 0),
#  (1, u'Quarter', u'INT', 0, None, 0),
#  (2, u'Month', u'INT', 0, None, 0),
#  (3, u'DayOfMonth', u'INT', 0, None, 0),
#  (4, u'DayOfWeek', u'INT', 0, None, 0),
#  (5, u'FlightDate', u'DATE', 0, None, 0),
#  (6, u'Reporting_Airline', u'VARCHAR(5)', 0, None, 0),
#  (7, u'DOT_ID_Reporting_Airline', u'INT', 0, None, 0),
#  (8, u'IATA_CODE_Reporting_Airline', u'VARCHAR(5)', 0, None, 0),
#  (9, u'Tail_Number', u'VARCHAR(20)', 0, None, 0),
#  (10, u'Flight_Number_Reporting_Airline', u'VARCHAR(20)', 0, None, 0),
#  (11, u'OriginAirportId', u'INT', 0, None, 0),
#  (12, u'OriginAirportSeqId', u'INT', 0, None, 0),
#  (13, u'OriginCityMarketId', u'INT', 0, None, 0),
#  (14, u'Origin', u'VARCHAR(3)', 0, None, 0),
#  (15, u'OriginCityName', u'VARCHAR(250)', 0, None, 0),
#  (16, u'OriginStateAbr', u'VARCHAR(2)', 0, None, 0),
#  (17, u'OriginStateFips', u'VARCHAR(30)', 0, None, 0),
#  (18, u'OriginStateNm', u'VARCHAR(250)', 0, None, 0),
#  (19, u'OriginWac', u'INT', 0, None, 0),
#  (20, u'DestAirportId', u'INT', 0, None, 0),
#  (21, u'DestAirportSeqId', u'INT', 0, None, 0),
#  (22, u'DestCityMarketId', u'INT', 0, None, 0),
#  (23, u'Dest', u'VARCHAR(3)', 0, None, 0),
#  (24, u'DestCityName', u'VARCHAR(250)', 0, None, 0),
#  (25, u'DestStateAbr', u'VARCHAR(2)', 0, None, 0),
#  (26, u'DestStateFips', u'VARCHAR(10)', 0, None, 0),
#  (27, u'DestStateNm', u'VARCHAR(250)', 0, None, 0),
#  (28, u'DestWac', u'INT', 0, None, 0),
#  (29, u'CrsDepTime', u'VARCHAR(4)', 0, None, 0),
#  (30, u'DepTime', u'VARCHAR(4)', 0, None, 0),
#  (31, u'DepDelay', u'INT', 0, None, 0),
#  (32, u'DepDelayMinutes', u'REAL', 0, None, 0),
#  (33, u'DepDel15', u'REAL', 0, None, 0),
#  (34, u'DepDelayGroup', u'REAL', 0, None, 0),
#  (35, u'DepTimeBlk', u'VARCHAR(50)', 0, None, 0),
#  (36, u'TaxiOut', u'REAL', 0, None, 0),
#  (37, u'WheelsOff', u'VARCHAR(4)', 0, None, 0),
#  (38, u'WheelsOn', u'VARCHAR(4)', 0, None, 0),
#  (39, u'TaxiIn', u'REAL', 0, None, 0),
#  (40, u'CrsArrTime', u'VARCHAR(4)', 0, None, 0),
#  (41, u'ArrTime', u'VARCHAR(4)', 0, None, 0),
#  (42, u'ArrDelay', u'REAL', 0, None, 0),
#  (43, u'ArrDelayMinutes', u'REAL', 0, None, 0),
#  (44, u'ArrDel15', u'REAL', 0, None, 0),
#  (45, u'ArrDelayGroup', u'INT', 0, None, 0),
#  (46, u'ArrTimeBlk', u'VARCHAR(50)', 0, None, 0),
#  (47, u'Cancelled', u'REAL', 0, None, 0),
#  (48, u'CancellationCode', u'VARCHAR(250)', 0, None, 0),
#  (49, u'Diverted', u'REAL', 0, None, 0),
#  (50, u'CrsElapsedTime', u'REAL', 0, None, 0),
#  (51, u'ActualElapsedTime', u'REAL', 0, None, 0),
#  (52, u'AirTime', u'REAL', 0, None, 0),
#  (53, u'Flights', u'REAL', 0, None, 0),
#  (54, u'Distance', u'REAL', 0, None, 0),
#  (55, u'DistanceGroup', u'INT', 0, None, 0),
#  (56, u'CarrierDelay', u'REAL', 0, None, 0),
#  (57, u'WeatherDelay', u'REAL', 0, None, 0),
#  (58, u'NasDelay', u'REAL', 0, None, 0),
#  (59, u'SecurityDelay', u'REAL', 0, None, 0),
#  (60, u'LateAircraftDelay', u'REAL', 0, None, 0),
#  (61, u'FirstDepTime', u'VARCHAR(250)', 0, None, 0),
#  (62, u'TotalAddGtime', u'REAL', 0, None, 0),
#  (63, u'LongestAddGtime', u'REAL', 0, None, 0),
#  (64, u'DivAirportLandings', u'INT', 0, None, 0),
#  (65, u'DivReachedDest', u'REAL', 0, None, 0),
#  (66, u'DivActualElapsedTime', u'REAL', 0, None, 0),
#  (67, u'DivArrDelay', u'REAL', 0, None, 0),
#  (68, u'DivDistance', u'REAL', 0, None, 0),
#  (69, u'Div1Airport', u'VARCHAR(3)', 0, None, 0),
#  (70, u'Div1AirportId', u'INT', 0, None, 0),
#  (71, u'Div1AirportSeqId', u'INT', 0, None, 0),
#  (72, u'Div1WheelsOn', u'VARCHAR(4)', 0, None, 0),
#  (73, u'Div1TotalGtime', u'REAL', 0, None, 0),
#  (74, u'Div1LongestGtime', u'REAL', 0, None, 0),
#  (75, u'Div1WheelsOff', u'VARCHAR(4)', 0, None, 0),
#  (76, u'Div1TailNum', u'VARCHAR(20)', 0, None, 0),
#  (77, u'Div2Airport', u'VARCHAR(3)', 0, None, 0),
#  (78, u'Div2AirportId', u'INT', 0, None, 0),
#  (79, u'Div2AirportSeqId', u'INT', 0, None, 0),
#  (80, u'Div2WheelsOn', u'VARCHAR(4)', 0, None, 0),
#  (81, u'Div2TotalGtime', u'REAL', 0, None, 0),
#  (82, u'Div2LongestGtime', u'REAL', 0, None, 0),
#  (83, u'Div2WheelsOff', u'VARCHAR(4)', 0, None, 0),
#  (84, u'Div2TailNum', u'VARCHAR(20)', 0, None, 0),
#  (85, u'Div3Airport', u'VARCHAR(3)', 0, None, 0),
#  (86, u'Div3AirportId', u'INT', 0, None, 0),
#  (87, u'Div3AirportSeqId', u'INT', 0, None, 0),
#  (88, u'Div3WheelsOn', u'VARCHAR(4)', 0, None, 0),
#  (89, u'Div3TotalGtime', u'REAL', 0, None, 0),
#  (90, u'Div3LongestGtime', u'REAL', 0, None, 0),
#  (91, u'Div3WheelsOff', u'VARCHAR(4)', 0, None, 0),
#  (92, u'Div3TailNum', u'VARCHAR(20)', 0, None, 0),
#  (93, u'Div4Airport', u'VARCHAR(3)', 0, None, 0),
#  (94, u'Div4AirportId', u'INT', 0, None, 0),
#  (95, u'Div4AirportSeqId', u'INT', 0, None, 0),
#  (96, u'Div4WheelsOn', u'VARCHAR(4)', 0, None, 0),
#  (97, u'Div4TotalGtime', u'REAL', 0, None, 0),
#  (98, u'Div4LongestGtime', u'REAL', 0, None, 0),
#  (99, u'Div4WheelsOff', u'VARCHAR(4)', 0, None, 0),
#  (100, u'Div4TailNum', u'VARCHAR(20)', 0, None, 0),
#  (101, u'Div5Airport', u'VARCHAR(3)', 0, None, 0),
#  (102, u'Div5AirportId', u'INT', 0, None, 0),
#  (103, u'Div5AirportSeqId', u'INT', 0, None, 0),
#  (104, u'Div5WheelsOn', u'VARCHAR(4)', 0, None, 0),
#  (105, u'Div5TotalGtime', u'REAL', 0, None, 0),
#  (106, u'Div5LongestGtime', u'REAL', 0, None, 0),
#  (107, u'Div5WheelsOff', u'VARCHAR(4)', 0, None, 0),
#  (108, u'Div5TailNum', u'VARCHAR(20)', 0, None, 0)]

# %%
# %%sql
# SELECT *
# from unique_carriers
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'02Q', u'Titan Airways'),
#  (u'04Q', u'Tradewind Aviation'),
#  (u'05Q', u'Comlux Aviation, AG'),
#  (u'06Q', u'Master Top Linhas Aereas Ltd.'),
#  (u'07Q', u'Flair Airlines Ltd.'),
#  (u'09Q', u'Swift Air, LLC d/b/a Eastern Air Lines d/b/a Eastern'),
#  (u'0BQ', u'DCA'),
#  (u'0CQ', u'ACM AIR CHARTER GmbH'),
#  (u'0FQ', u'Maine Aviation Aircraft Charter, LLC'),
#  (u'0GQ', u'Inter Island Airways, d/b/a Inter Island Air'),
#  (u'0HQ', u'Polar Airlines de Mexico d/b/a Nova Air'),
#  (u'0J', u'JetClub AG'),
#  (u'0JQ', u'Vision Airlines'),
#  (u'0LQ', u'Metropix UK, LLP.'),
#  (u'0MQ', u'Multi-Aero, Inc. d/b/a Air Choice One'),
#  (u'0OQ', u'Open Skies'),
#  (u'0Q', u'Flying Service N.V.'),
#  (u'0QQ', u'TAG Aviation (UK) Ltd.'),
#  (u'0RQ', u'TAG Aviation Espana S.L.'),
#  (u'0TQ', u'Corporatejets, XXI'),
#  (u'0UQ', u'Comlux Malta, Ltd.'),
#  (u'0VQ', u'Ocean Sky (UK) Limited'),
#  (u'0WQ', u'Avjet Corporation'),
#  (u'0YQ', u'Comlux Malta Ltd.'),
#  (u'10Q', u'Swiss Air Ambulance'),
#  (u'12Q', u'Unijet'),
#  (u'13Q', u'Chartright Air Inc.'),
#  (u'14Q', u'London Air Services Limited'),
#  (u'15Q', u'Air Alsie A/S'),
#  (u'17Q', u'Albinati Aeronautics SA'),
#  (u'1AQ', u'Via Airlines d/b/a Charter Air Transport'),
#  (u'1BQ', u'Eastern Airlines f/k/a Dynamic Airways, LLC'),
#  (u'1DQ', u'Island Airlines LLC'),
#  (u'1EQ', u'KaiserAir, Inc.'),
#  (u'1FQ', u'Alsek Air'),
#  (u'1HQ', u'International Jet Management GmbH'),
#  (u'1I', u'Sky Trek International Airlines'),
#  (u'1IQ', u'Jet link AG'),
#  (u'1JQ', u'Exec Direct Aviation Services Limited'),
#  (u'1LQ', u'Bertelsmann Aviation GmbH'),
#  (u'1MQ', u'Twin Cities Air Service LLC'),
#  (u'1NQ', u'JSC The 224th Flight Unit State Airlines'),
#  (u'1PQ', u'Makani Kai Air Charters'),
#  (u'1QQ', u'City Wings Inc dba Seaflight'),
#  (u'1RQ', u'Sun Air Express LLC dba Sun Air International'),
#  (u'1SQ', u'Star Marianas Air Inc.'),
#  (u'1TQ', u'Rhoades Aviation dba Transair'),
#  (u'1UQ', u'Gainjet Aviation SA'),
#  (u'1WQ', u'Ultimate JetCharters LLC dba Ultimate Air Shuttle'),
#  (u'1XQ', u'Dassault Falcon Service'),
#  (u'1YQ', u'Air Charter, Inc d/b/a Air Flamenco'),
#  (u'1ZQ', u'Comlux Aruba NV'),
#  (u'20Q', u'Orange Air'),
#  (u'22Q', u'Gem Air LLC'),
#  (u'23Q', u'Songbird Airways Inc.'),
#  (u'24Q', u'Blue Jet SP Z o o'),
#  (u'25Q', u'Mjet GmbH'),
#  (u'26Q', u'Albinati aviation Limited'),
#  (u'27Q', u'Jet Aviation Flight Services, Inc.'),
#  (u'28Q', u'Menagerie Enterprises Inc d/b/a Monarch Air'),
#  (u'29Q', u'Erickson Helicopters'),
#  (u'2AQ', u'ABS JETS A.S'),
#  (u'2BQ', u'Air Medical Ltd.'),
#  (u'2E', u'Smokey Bay Air Inc.'),
#  (u'2EQ', u'J&M Alaska Air Tours, Inc. d/b/a Alaska Air Transit'),
#  (u'2F', u'Frontier Flying Service'),
#  (u'2GQ', u'Cavok Air LLC'),
#  (u'2HQ', u'Elite Airways LLC'),
#  (u'2JQ', u'Delux Public Charter LLC'),
#  (u'2K', u'Aerolineas Galapagos S A Aerogal'),
#  (u'2KQ', u'Longtail Aviation Ltd.'),
#  (u'2LQ', u'Tropic Ocean Airways LLC'),
#  (u'2M', u'Midway Express Airlines'),
#  (u'2NQ', u'LIMA NY Corp d/b/a Fly The Whale d/b/a Tailwind'),
#  (u'2O', u'Island Air Service'),
#  (u'2OQ', u'Talofa Airways Limited'),
#  (u'2P', u'Air Philippines Corp d/b/a Airphil Express, Philippines Airlines'),
#  (u'2PQ', u'21 Air LLC'),
#  (u'2R', u'Regal Air'),
#  (u'2RQ', u'Luxaviation S A'),
#  (u'2T', u'Canada 3000 Airlines Ltd.'),
#  (u'2TQ', u'Trans Northern Airways d/b/a Air Unlimited Charter Services'),
#  (u'2U', u'Valley Air Express Inc.'),
#  (u'2UQ', u'Svenskt Industriflyg AB'),
#  (u'30Q', u'Public Charters, Inc. d/b/a North Country Sky d/b/a Regional Sky d/b/a Texas Sky'),
#  (u'34Q', u'Polaris Aviation Solutions, LLC'),
#  (u'35Q', u'Aztec Worldwide Airlines, Inc.  d/b/a  Aztec Airways'),
#  (u'36Q', u'Air Hamburg Luftverkehrsgesellschaft mbH'),
#  (u'37', u'Zeal 320'),
#  (u'37Q', u'Hillwood Airways, LLC  f/k/a   ATX Air Services, LLC'),
#  (u'38Q', u'Key Lime Air Corporation'),
#  (u'3AQ', u'Maritime Helicopters, Inc.'),
#  (u'3BQ', u'Nealco Air Charter Services, Inc.  d/b/a  Watermakers Air'),
#  (u'3C', u'Regions Air, Inc.'),
#  (u'3CQ', u'Andrew Airways, Inc.'),
#  (u'3DQ', u'Rectrix Aviation, Inc.'),
#  (u'3EQ', u'Scott Aviation, LLC  d/b/a  Silver Air'),
#  (u'3F', u'Pacific Airways, Inc.'),
#  (u'3FQ', u'Western Air Charter, Inc.  d/b/a  Jet Edge'),
#  (u'3GQ', u'Aviateca, S.A.'),
#  (u'3M', u'Silver Airways'),
#  (u'3S', u'AeroLogic GmbH'),
#  (u'3SD', u'Compagnie Aerienne Inter Regionale Express dba Air Antilles Express & Air Guyane'),
#  (u'3U', u'Sichuan Airlines Co Ltd.'),
#  (u'4B', u'Boutique Air'),
#  (u'4B (1)', u'Olson Air Service'),
#  (u'4C', u'Aerovias de Intergracian Regional'),
#  (u'4E', u'British Airtours Limited'),
#  (u'4H', u'Belize Trans Air'),
#  (u'4M', u'LAN Argentina'),
#  (u'4M (1)', u'Lan Dominica'),
#  (u'4N', u'Air North'),
#  (u'4O', u'ABC Aerolineas SA de CV dba Interjet'),
#  (u'4R', u'Regent Air Corporation'),
#  (u'4S', u'Sol Air (Aero Hunduras)'),
#  (u'4S (1)', u'Conner Air Lines Inc.'),
#  (u'4T', u'Belair Airlines Ltd.'),
#  (u'4W', u'Warbelow'),
#  (u'4Y', u'Yute Air Aka Flight Alaska'),
#  (u'5B', u'Bellair Inc.'),
#  (u'5C', u'C.A.L Cargo Airlines'),
#  (u'5D', u'Aerolitoral'),
#  (u'5F', u'Arctic Circle Air Service'),
#  (u'5G', u'Skyservice Airlines, Inc.'),
#  (u'5G (1)', u'Queen Air'),
#  (u'5J', u'Cebu Air Inc d/b/a Cebu Pacific Air'),
#  (u'5J (1)', u'Private Jet Expeditions'),
#  (u'5L', u'Aerosur'),
#  (u'5V', u'Tatonduk Outfitters Limited d/b/a Everts Air Alaska and Everts Air Cargo'),
#  (u'5X', u'United Parcel Service'),
#  (u'5Y', u'Atlas Air Inc.'),
#  (u'6A', u'Aviacsa Airlines'),
#  (u'6B', u'TUIfly Nordic A.B.'),
#  (u'6C', u'Cape Smythe Air Service'),
#  (u'6F', u'Laker Airways Inc.'),
#  (u'6H', u'Israir Airlines'),
#  (u'6P', u'Pacific East Air Inc.'),
#  (u'6R', u'Aerounion Aerotransporte de Carga Union SA de CV'),
#  (u'6U', u'Air Ukraine'),
#  (u'6Y', u'Nicaraguense De Aviacion Sa'),
#  (u'7B', u'Krasair'),
#  (u'7C', u'Jeju Air Co Ltd.'),
#  (u'7F', u'First Air'),
#  (u'7G', u'MK Airlines Ltd.'),
#  (u'7G (1)', u'Bellair Inc. (1)'),
#  (u'7H', u'Era Aviation'),
#  (u'7I', u'Insel Air International B V'),
#  (u'7L', u'Silk Way West Airlines'),
#  (u'7M', u'Aeromonterrey S.A.'),
#  (u'7N', u'Inland Aviation Services'),
#  (u'7P', u'Apa International Air S.A.'),
#  (u'7Q', u'Pan American World Airways Dominicana'),
#  (u'7S', u'Ryan Air f/k/a Arctic Transportation'),
#  (u'7S (1)', u'Skystar International Inc.'),
#  (u'7Z', u'Lb Limited'),
#  (u'8C', u'Air Transport International'),
#  (u'8D', u'Dynamic Aviation, Inc. d/b/a Beacon'),
#  (u'8E', u'Bering Air Inc.'),
#  (u'8F', u'Wilburs Inc.'),
#  (u'8I', u'Inselair Aruba NV'),
#  (u'8J', u'Jetall Airways'),
#  (u'8L', u'Servicio Aereo Leo Lopez'),
#  (u'8N', u'Flagship Airlines Inc.'),
#  (u'8Q', u'Baker Aviation Inc.'),
#  (u'8R', u'Edelweiss Air Ag'),
#  (u'8V', u'Wright Air Service'),
#  (u'9E', u'Endeavor Air Inc.'),
#  (u'9J', u'Pacific Island Aviation'),
#  (u'9K', u'Cape Air'),
#  (u'9L', u'Colgan Air'),
#  (u'9M', u'Central Mountain Air'),
#  (u'9N', u'ANA & JP Express Co. Ltd.'),
#  (u'9R', u'Flagship Express Services'),
#  (u'9S', u'Southern Air Inc.'),
#  (u'9T', u'TravelspanGT, Inc. S.A.'),
#  (u'9V', u'Avior Airlines, C.A.'),
#  (u'9W', u'Jet Airways (India) Limited'),
#  (u'A0', u"Elysair d/b/a L'Avion"),
#  (u'A2', u'Cielos De Peru'),
#  (u'A4', u'Southern Wind Airlines'),
#  (u'A7', u'Air Comet S.A.'),
#  (u'A7 (1)', u'Air 21'),
#  (u'AA', u'American Airlines Inc.'),
#  (u'AAA', u'Associated Aviation Act.'),
#  (u'AAB', u'Abelag Aviation AG'),
#  (u'AAB (1)', u'Antilles Air Boats Inc.'),
#  (u'AAE', u'AAA Airlines'),
#  (u'AAI', u'Audi Air Inc.'),
#  (u'AAL', u'Argosy Air Lines Inc.'),
#  (u'AAP', u'Armstrong Air Service Inc.'),
#  (u'AAQ', u'Advance Air Charters'),
#  (u'AAR', u'Altair Airlines Inc.'),
#  (u'AAT', u'Air Sunshine Inc.'),
#  (u'AAV', u'Alpine Air'),
#  (u'AAZ', u'Alaska Aeronautical Indust.'),
#  (u'AB', u'Air Berlin PLC and CO'),
#  (u'ABH', u'Air Bahia'),
#  (u'ABI', u'Airbama Incorporated'),
#  (u'ABO', u'Aeronaves Boringuena Inc.'),
#  (u'ABX', u'ABX Air Inc'),
#  (u'AC', u'Air Canada'),
#  (u'ACA', u'Alaska Central Airways Inc.'),
#  (u'ACD', u'Academy Airlines'),
#  (u'ACG', u'Air Cargo Express Inc.'),
#  (u'ACH', u'Island Airlines Hawaii Inc.'),
#  (u'ACI', u'AAA-Action Air Carrier Inc.'),
#  (u'ACJ', u'Atlantic Coast Jet Inc.'),
#  (u'ACK', u'Air Central Inc.'),
#  (u'ACL', u'Check-Air Inc.'),
#  (u'ACN', u'Alliance Airlines'),
#  (u'ACO', u'Air Cargo Enterprises Inc.'),
#  (u'ACP', u'Air Chaparral Inc.'),
#  (u'ACQ', u'Aeronautica De Cancun'),
#  (u'ACS', u'Alamo Commuter Airlines'),
#  (u'ACT', u'Air Central Inc. (1)'),
#  (u'ACW', u'Transwest Air Express'),
#  (u'AD', u'Azul Linhas Aereas Brazileiras S A'),
#  (u'AD (1)', u'Avia Leasing Company'),
#  (u'ADB', u'Antonov Company'),
#  (u'ADQ', u'Aeronaves Del Peru'),
#  (u'ADR', u'Adirondack Airlines'),
#  (u'ADV', u'Advantage Airlines'),
#  (u'AE', u'Air Europe Limited'),
#  (u'AEC', u'Astec Air East Inc.'),
#  (u'AED', u'Air East Of Delaware Inc.'),
#  (u'AEF', u'Aero Freight'),
#  (u'AEO', u'Aero Coach'),
#  (u'AEQ', u'Air Caravane Inc.'),
#  (u'AEX', u'Air Excursions LLC (1)'),
#  (u'AF', u'Compagnie Natl Air France'),
#  (u'AFA', u'American Flag Airlines Inc.'),
#  (u'AFE', u'Air Florida Express'),
#  (u'AFG', u'American Flight Group'),
#  (u'AFQ', u'Aero B Venezuela C.A.'),
#  (u'AFS', u'Arcata Flying Service'),
#  (u'AG', u'Arubaanse Luchtvaart Maatschappij NV dba Aruba Airlines'),
#  (u'AGA', u'Air Cargo America Inc.'),
#  (u'AGQ', u'Argo S. A.'),
#  (u'AHA', u'Air Alpha'),
#  (u'AHC', u'Air Hawaii'),
#  (u'AHQ', u'Air National'),
#  (u'AI', u'National Aviation Company of India Limited d/b/a Air India'),
#  (u'AIA', u'All Island Air'),
#  (u'AIC', u'Air Caribbean'),
#  (u'AIE', u'Air Express Inc.'),
#  (u'AIG', u'Airgo Inc.'),
#  (u'AIK', u'Air Ketchum Idaho Inc.'),
#  (u'AIM', u'Air Mont. Inc.'),
#  (u'AIN', u'Air Indiana'),
#  (u'AIQ', u'Norontair'),
#  (u'AIT', u'Airways International'),
#  (u'AIY', u'Alliance Air'),
#  (u'AJ', u'Air Micronesia Inc.'),
#  (u'AJQ', u'Aerodynamics Inc. d/b/a SkyValue d/b/a SkyValue Airways'),
#  (u'AKQ', u'Airmark Airlines Inc.'),
#  (u'AL', u'Skyway Airlines'),
#  (u'ALD', u'Allied Airlines'),
#  (u'ALE', u'Air-Lift Associates Inc.'),
#  (u'ALI', u'Brandt Air'),
#  (u'ALK', u'Air Link Airways'),
#  (u'ALL', u'All Seasons Air Pacific'),
#  (u'ALQ', u'Alberta Northern Airlines'),
#  (u'ALS', u'Air L.A.'),
#  (u'ALT', u'Altus Airlines'),
#  (u'ALU', u'Aleutian Air'),
#  (u'ALX', u'Atlanta Express'),
#  (u'AM', u'Aeromexico'),
#  (u'AMA', u'North American Airlines Inc.'),
#  (u'AME', u'Americair Inc.'),
#  (u'AMI', u'American Inter-Island Inc.'),
#  (u'AMQ', u'Ameristar Air Cargo'),
#  (u'AMR', u'AvAir'),
#  (u'AMT', u'American Air Transport'),
#  (u'AN', u'ADVANCED AIR, LLC'),
#  (u'ANB', u'Air Nebraska Inc.'),
#  (u'ANC', u'Atlantic Air'),
#  (u'AND', u'Southcentral Air Inc.'),
#  (u'ANI', u'Dash Air Corporation'),
#  (u'ANM', u'Airways Of New Mexico Inc.'),
#  (u'ANO', u'Metro Air Northeast Vermont'),
#  (u'ANT', u'Air North/Nenana'),
#  (u'AO', u'Aviacion Y Comercio S.A.'),
#  (u'AOI', u'Trans New York'),
#  (u'AON', u'Action Airlines'),
#  (u'AOQ', u'Aerovias S.A.'),
#  (u'AOR', u'Air New Orleans'),
#  (u'APE', u'Air Cape'),
#  (u'APH', u'Alpha Air'),
#  (u'API', u'Arizona Pacific Inc.'),
#  (u'APL', u'Appalachian Flying Service'),
#  (u'APN', u'Aspen Airways Inc.'),
#  (u'APQ', u'Alas De Transporte International'),
#  (u'APS', u'Air Spirit Inc.'),
#  (u'APY', u'Air Polynesia Inc.'),
#  (u'AQ', u'Aloha Airlines Inc.'),
#  (u'AQQ', u'Air Charter (Safa)'),
#  (u'AR', u'Aerolineas Argentinas'),
#  (u'ARA', u'Air Resorts Airlines'),
#  (u'ARB', u'Air Caribe International'),
#  (u'ARD', u'Airlift International'),
#  (u'ARI', u'Arizona Aero Corp.'),
#  (u'ARM', u'Airmarc Airlines Inc.'),
#  (u'ARN', u'Arnold Aviation'),
#  (u'ARO', u'Air Oregon'),
#  (u'ARP', u'Airspur Helicopters Inc.'),
#  (u'ARQ', u'Aerovias Colombianas Arca'),
#  (u'ARR', u'Arrowhead Airways Inc.'),
#  (u'ARS', u'Air Sedona'),
#  (u'ARZ', u'Arizona Airways'),
#  (u'AS', u'Alaska Airlines Inc.'),
#  (u'ASC', u'Air South Inc.'),
#  (u'ASD', u'Amistad Airlines'),
#  (u'ASH', u'Air South'),
#  (u'ASI', u'Alpine Air Services Inc.'),
#  (u'ASN', u'Air Casino'),
#  (u'ASP', u'Asap Air Inc.'),
#  (u'ASQ', u'Aerosur (1)'),
#  (u'ASR', u'Astor Air'),
#  (u'AST', u'Astro Airways'),
#  (u'ASU', u'Air South (1)'),
#  (u'ASW', u'Sunrise Airlines Inc.'),
#  (u'AT', u'Royal Air Maroc'),
#  (u'ATH', u'Air Southeast'),
#  (u'ATN', u'Air Atlantic Airlines Inc.'),
#  (u'ATO', u'Pacific National Airways'),
#  (u'ATQ', u'Aero Tranportes Panamenos'),
#  (u'ATS', u'Atlantis Airlines Inc.'),
#  (u'ATT', u'Aerotransit Inc.'),
#  (u'ATX', u'Air Carolina'),
#  (u'AUX', u'Austin Express Inc.'),
#  (u'AV', u'Aerovias Nacl De Colombia'),
#  (u'AVA', u'Air Vectors Airways'),
#  (u'AVC', u'Av Center Inc.'),
#  (u'AVG', u'Airvantage'),
#  (u'AVI', u'Aero Virgin Islands Corp.'),
#  (u'AVL', u'Aviation Sales'),
#  (u'AVQ', u'Aero Laguna S.A. De C.V.'),
#  (u'AVR', u'Air Vermont Inc.'),
#  (u'AVS', u'Aviation Services'),
#  (u'AVZ', u'Southern Jersey Airways'),
#  (u'AWA', u'Air West Airlines'),
#  (u'AWQ', u'Aermediterranea S.P.A.'),
#  (u'AX', u'Trans States Airlines'),
#  (u'AXQ', u'Aeron International Airlines Inc.'),
#  (u'AY', u'Finnair Oy'),
#  (u'AYQ', u'Aerodan S.A. De C.V.'),
#  (u'AZ', u'Compagnia Aerea Italiana'),
#  (u'AZP', u'Arizona Pacific Airways'),
#  (u'AZQ', u'Anglo Airlines Ltd.'),
#  (u'B0', u'Dreamjet SAS Dba La Compagnie'),
#  (u'B6', u'JetBlue Airways'),
#  (u'BA', u'British Airways Plc'),
#  (u'BAA', u'Aero International Airlines'),
#  (u'BAC', u'Business Aircraft Corp.'),
#  (u'BAH', u'Brennan & Hargreaves Inc.'),
#  (u'BAK', u'Bankair Inc.'),
#  (u'BAN', u'Bangor International Air'),
#  (u'BAQ', u'Aero Rentas De Coahuila S.A. De C.V.'),
#  (u'BAR', u'Bard-Air Corp.'),
#  (u'BAT', u'West Penn Commuter'),
#  (u'BAY', u'Burlington Aeroplane Co.'),
#  (u'BBQ', u'Balair Ag'),
#  (u'BC', u'Skymark Airlines Inc.'),
#  (u'BCA', u'Baja Cortez Airlines'),
#  (u'BCQ', u'Bradley Air Services Ltd.'),
#  (u'BD', u'British Midland Airways Ltd.'),
#  (u'BDE', u'Jet Express'),
#  (u'BDQ', u'Aerotaxis De Aguascalientes S.A. De C.V.'),
#  (u'BE', u'Braniff International Airlines Inc.'),
#  (u'BEA', u'Business Express Airlines'),
#  (u'BEN', u'Bennington Aviation Inc.'),
#  (u'BEQ', u'Air Belgium'),
#  (u'BES', u'Aeroservices Executive'),
#  (u'BEY', u'Beyer Aviation'),
#  (u'BF', u'Markair Inc.'),
#  (u'BFG', u'Million Air'),
#  (u'BFQ', u'Buffalo Airways Inc.'),
#  (u'BG', u'Biman Bangladesh Airlines'),
#  (u'BGQ', u"Airbus Transport Internat'l"),
#  (u'BHK', u'Blackhawk Airways Inc.'),
#  (u'BHO', u'Bighorn Airways Inc.'),
#  (u'BHQ', u'Turks Air Ltd. (1)'),
#  (u'BIA', u'Big Island Air'),
#  (u'BIQ', u'Servicios Aeronauticos Z S.A. De C.V.'),
#  (u'BIR', u'Birchwood Air Service'),
#  (u'BJQ', u'Taxirey S.A. De C.V.'),
#  (u'BLQ', u'Air Bvi Limited'),
#  (u'BM', u'Belize Air International Ltd.'),
#  (u'BMT', u'Bremerton Aviation Inc.'),
#  (u'BN', u'Britannia Airways GmbH'),
#  (u'BN (1)', u'Braniff Inc.'),
#  (u'BNQ', u'NetJets Large Aircraft Company L.L.C.'),
#  (u'BOA', u'Boise Air Service'),
#  (u'BOI', u'Bo-S-Aire Airlines Inc.'),
#  (u'BOQ', u'Transp. Aereos Bolivianos'),
#  (u'BQ', u'Aeromar C. Por A.'),
#  (u'BR', u'Eva Airways Corporation'),
#  (u'BR (1)', u'Cal Air International Ltd.'),
#  (u'BRK', u'Barken International'),
#  (u'BRO', u'Brower Airways Inc.'),
#  (u'BRW', u'Barrow Air'),
#  (u'BTQ', u'Brasair Transportes Aereos'),
#  (u'BUH', u'Business Helicopters'),
#  (u'BUQ', u'Wrangler Aviation Inc.'),
#  (u'BUQ (1)', u'Blue Bell Inc.'),
#  (u'BUR', u'Burlington Airways Inc.'),
#  (u'BW', u'Caribbean Airlines Limited'),
#  (u'BX', u'Air Busan'),
#  (u'BXQ', u'Spantax S. A.'),
#  (u'BY', u'Britannia Airways Ltd.'),
#  (u'BYA', u'Bay Air'),
#  (u'BZQ', u'Abaco Air, Ltd.'),
#  (u'C5', u'Commutair Aka Champlain Enterprises, Inc.'),
#  (u'C6', u'Canjet Airlines'),
#  (u'C8', u'Cargolux Italia SpA'),
#  (u'C8 (1)', u'Chicago Express Airlines'),
#  (u'CA', u'Air China'),
#  (u'CAC', u'Coleman Air Transport'),
#  (u'CAF', u'California Seaboard'),
#  (u'CAI', u'Crawford Aviation Inc.'),
#  (u'CAM', u'C & M Airlines'),
#  (u'CAP', u'Metro Air Northeast N Y'),
#  (u'CAQ', u'Challenge Air Luftverkehrs GmbH'),
#  (u'CAT', u'Catalina Airlines Inc.'),
#  (u'CAV', u'Air Virginia'),
#  (u'CAZ', u'CAT Aviation'),
#  (u'CB', u'Air One Inc.'),
#  (u'CBA', u'Carriba Air Inc.'),
#  (u'CC', u'Air Atlanta Icelandic'),
#  (u'CC (1)', u'Air Atlanta Inc.'),
#  (u'CCA', u'Cityhop'),
#  (u'CCO', u'Chester County Aviation'),
#  (u'CDQ', u'Kitty Hawk International'),
#  (u'CEN', u'Cen-Tex Airlines Inc.'),
#  (u'CEQ', u'All Canada Express'),
#  (u'CET', u'Century Airlines (Cal)'),
#  (u'CF', u'Compan. De Aviacion Faucett'),
#  (u'CGA', u'Chicago Airlines'),
#  (u'CGL', u'Viking International Airlines Inc.'),
#  (u'CGO', u'Chicago Air Taxi'),
#  (u'CH', u'Bemidji Airlines'),
#  (u'CHD', u'Chandler Flyer'),
#  (u'CHE', u'Charter Airlines'),
#  (u'CHF', u'Hammonds Commuter Air Serv.'),
#  (u'CHI', u'Chitina Air Service'),
#  (u'CHL', u'Channel Flying Inc.'),
#  (u'CHO', u'Choi Aviation Inc.'),
#  (u'CHS', u'Christman Air System'),
#  (u'CHT', u'Charter One'),
#  (u'CI', u'China Airlines Ltd.'),
#  (u'CIQ', u'A/S Conair'),
#  (u'CIS', u'Cal Sierra Airlines'),
#  (u'CJ', u'Colgan Airways Inc.'),
#  (u'CK', u'China Cargo Airline'),
#  (u'CKI', u'Inlet Airlines'),
#  (u'CL', u'Capitol International Inc.'),
#  (u'CLB', u'Columbia Pacific Airlines'),
#  (u'CLD', u'Hawaii Pacific Helicopters'),
#  (u'CLF', u'California Air Shuttle'),
#  (u'CLQ', u'Aero Transcolombiana'),
#  (u'CM', u'Compania Panamena (Copa)'),
#  (u'CMB', u'Combs Airways Inc.'),
#  (u'CMD', u'Command Airways Inc.'),
#  (u'CMQ', u'Servicio De Carga Aerea Sa'),
#  (u'CMR', u'Commuter Airlines (Ca)'),
#  (u'CNN', u'Centennial Airlines'),
#  (u'CO', u'Continental Air Lines Inc.'),
#  (u'COB', u'Cotton Belt Aviation Inc.'),
#  (u'COC', u'Cochise Airlines Inc.'),
#  (u'COK', u'Coker Aviation Inc.'),
#  (u'COL', u'Presidential Express'),
#  (u'COM', u'Commutair'),
#  (u'COR', u'Coral Air Inc.'),
#  (u'COS', u'Cosmopolitan Comm. Airline'),
#  (u'COT', u'Southeastern Commuter'),
#  (u'COU', u'Courtesy Air Service Inc.'),
#  (u'CP', u'Compass Airlines'),
#  (u'CP (1)', u'Canadian Airlines International Ltd.'),
#  (u'CPA', u'Capitol Air Lines'),
#  (u'CPC', u'Coastal Plains Commuter Inc.'),
#  (u'CPQ', u'Capitol Air Express Inc.'),
#  (u'CPT', u'Capitol Air'),
#  (u'CQI', u'Conquest Airline Corp.'),
#  (u'CRA', u'Commuter Airlines'),
#  (u'CRB', u'Caribair'),
#  (u'CRE', u'Caribbean Express Inc.'),
#  (u'CRH', u'Cresent Medivac'),
#  (u'CRN', u'Crown Aviaiton Inc.'),
#  (u'CRO', u'Crown Airways Inc.'),
#  (u'CRP', u'Corporate Air'),
#  (u'CRT', u'Crested Butte Air Service'),
#  (u'CRV', u'Acropolis Aviation Ltd.'),
#  (u'CS', u'Continental Micronesia'),
#  (u'CSA', u'Casino Airlines'),
#  (u'CSK', u'Catskill Airways Inc.'),
#  (u'CSL', u'Central States Air Lines'),
#  (u'CSM', u'Chisum Flying Service'),
#  (u'CSN', u'Casino Airlines (1)'),
#  (u'CSQ', u'Celtic Tech Jet Ltd.'),
#  (u'CTA', u'Century Airlines'),
#  (u'CTH', u'Cothron Aviation'),
#  (u'CTL', u'Coastal Air Transport'),
#  (u'CTQ', u'Custom Air Transport'),
#  (u'CTR', u'Chartair'),
#  (u'CUQ', u'Caicos Caribbean Airways'),
#  (u'CUS', u'Custom Air Service'),
#  (u'CV', u'Cargolux Airlines International S.A'),
#  (u'CVA', u'Catalina-Vegas Airlines'),
#  (u'CVQ', u'Caraven S.A.'),
#  (u'CW', u'Air Marshall Islands Inc.'),
#  (u'CWQ', u'Canadian Aviation Express'),
#  (u'CX', u'Cathay Pacific Airways Ltd.'),
#  (u'CYQ', u'Corse Air International'),
#  (u'CZ', u'China Southern Airlines'),
#  (u'CZ (1)', u'Cascade Airways Inc.'),
#  (u'CZQ', u'Aviation Concepts'),
#  (u'D7', u'Air Asia X Berhad dba Airasia X'),
#  (u'D8', u'Norwegian Air International Ltd.'),
#  (u'DA', u'Dan Air Services'),
#  (u'DAN', u'Danbury Airlines'),
#  (u'DAU', u'Dauphin Island Airways'),
#  (u'DC', u'Caribbean Air Cargo Co Ltd.'),
#  (u'DE', u'Condor Flugdienst'),
#  (u'DEA', u'Downeast Airlines Inc.'),
#  (u'DEC', u'Decatur Aviation'),
#  (u'DFS', u'Downeast Flying Service'),
#  (u'DH', u'Independence Air'),
#  (u'DH (1)', u'Discovery Airways Inc.'),
#  (u'DHL', u'DHL Airlines Inc.'),
#  (u'DHQ', u'DHL Aero Expresso'),
#  (u'DI', u'Norwegian Air UK Limited'),
#  (u'DIA', u'Drummond Island Air'),
#  (u'DIC', u'Dickman Aviation Services'),
#  (u'DIR', u'Northern Star'),
#  (u'DL', u'Delta Air Lines Inc.'),
#  (u'DM', u'Maersk Air I/S'),
#  (u'DO', u'Compania Dominicana De Avia'),
#  (u'DOL', u'Dolphin Airways Inc.'),
#  (u'DOQ', u'Aerolineas Dominicanas S A'),
#  (u'DPA', u'Desert Pacific Airways'),
#  (u'DPI', u'Desert Pacific Airlines Inc.'),
#  (u'DQQ', u'Caribwest Airways Ltd.'),
#  (u'DSA', u'Desert Sun Airlines'),
#  (u'DST', u'Desert Airlines'),
#  (u'DUL', u'Dulles Express'),
#  (u'DUZ', u'Summit Airlines Inc.'),
#  (u'DVO', u'Devoe Airlines'),
#  (u'DWN', u'Dawn Air'),
#  (u'DXA', u'Dolphin Express'),
#  (u'DY', u'Norwegian Air Shuttle ASA'),
#  (u'E0', u'EOS Airlines, Inc.'),
#  (u'E7', u'Estafeta Carga Aereas'),
#  (u'E72', u'European Aviation Air Charter'),
#  (u'E8', u'USAfrica Airways Inc.'),
#  (u'E9', u'Evelop Airlines SL'),
#  (u'E9 (1)', u'Boston-Maine Airways'),
#  (u'EA', u'Eastern Air Lines Inc.'),
#  (u'EAI', u'Executive Aviation Inc.'),
#  (u'EAQ', u'Executive Airlines, SL'),
#  (u'EAS', u'Eastern Caribbean Airways'),
#  (u'EAT', u'Eastman Airways Inc.'),
#  (u'EBQ', u'Execaire Aviation Ltd.'),
#  (u'ECA', u'Eagle Airlines (1)'),
#  (u'ECI', u'Eastern Carolina Aviation'),
#  (u'ECL', u'Eclipse Airlines'),
#  (u'ECQ', u'Trans American Charter'),
#  (u'ECR', u'East Coast Airways'),
#  (u'ED', u'Andes'),
#  (u'EDE', u'Ede Aire'),
#  (u'EE', u'Eastern Airlines Group Inc.'),
#  (u'EET', u'Exec Express II'),
#  (u'EEX', u'Exec Express'),
#  (u'EEZ', u'Eagle Aviation Inc.'),
#  (u'EFA', u'Executive Four Winds'),
#  (u'EFQ', u'Trans Europ. Airways France'),
#  (u'EGA', u'Eagle Airline'),
#  (u'EGJ', u'Eagle Jet Charter'),
#  (u'EGL', u'Eagle Commuter Airlines Inc.'),
#  (u'EH', u'Saeta Airlines'),
#  (u'EHA', u'East Hampton Aire Inc.'),
#  (u'EI', u'Aer Lingus Plc'),
#  (u'EIA', u'East. Indiana Aviation Sale'),
#  (u'EJQ', u'Aeroejecutivos C.A.'),
#  (u'EK', u'Emirates'),
#  (u'EKA', u'Air Pacific Inc.'),
#  (u'ELL', u'Ellis Air Taxi Inc.'),
#  (u'EM', u'Empire Airlines Inc.'),
#  (u'EMA', u'Emerald Airlines'),
#  (u'EME', u'Metro Express'),
#  (u'EMP', u'Empire Airlines Inc. (2)'),
#  (u'ENT', u'Enterprise Airlines Inc.'),
#  (u'EOQ', u'Aeroservicios Ecuatorianos'),
#  (u'EP', u'All Star Airlines Inc.'),
#  (u'EQ', u'Tame Linea Aerea del Ecuador Tme EP'),
#  (u'ER', u'Astar USA, LLC'),
#  (u'ERI', u'Erie Airways Inc.'),
#  (u'ERO', u'Empire Aero Service'),
#  (u'ERQ', u'Aero Trades (Western) Ltd.'),
#  (u'ESQ', u'Seagreen Air Transport'),
#  (u'ET', u'Ethiopian Airlines'),
#  (u'EU', u'Ecuatoriana De Aviacion'),
#  (u'EUQ', u'Air Atlanta Europe'),
#  (u'EV', u'ExpressJet Airlines Inc.'),
#  (u'EVA', u'Evanston Aviation'),
#  (u'EW', u'Eurowings GmbH'),
#  (u'EWA', u'Rio Grande Air'),
#  (u'EXA', u'Columbia Pacific Airlines (1)'),
#  (u'EXC', u'Hapag-Lloyd Executive GmbH'),
#  (u'EXC (1)', u'Executive Charter'),
#  (u'EXP', u'Express Airlines II'),
#  (u'EXQ', u'Export Air Del Peru S.A.'),
#  (u'EXR', u'Executive Transport'),
#  (u'EY', u'Etihad Airways'),
#  (u'EZ', u'Evergreen International Inc.'),
#  (u'F2', u'Omega Air Holdings d/b/a Focus Air'),
#  (u'F8', u'Freedom Airlines d/b/a HP Expr'),
#  (u'F9', u'Frontier Airlines Inc.'),
#  (u'FAA', u'Falwell Aviation Inc.'),
#  (u'FAC', u'Falcon Airways Inc.'),
#  (u'FAQ', u'Fast Air Carrier Ltd. (1)'),
#  (u'FAR', u'Federal Armored Service Inc.'),
#  (u'FB', u'Translift Airways Limited'),
#  (u'FBI', u'Young Flying Service'),
#  (u'FCA', u'Southern Airlines Inc.'),
#  (u'FCQ', u'Falcon Air Express'),
#  (u'FD', u'Air Puerto Rico Airlines'),
#  (u'FDA', u'Florida Airlines Inc.'),
#  (u'FDM', u'Freedom Airlines Inc.'),
#  (u'FDQ', u'Great American Airways'),
#  (u'FE', u'Primaris Airlines Inc.'),
#  (u'FF', u'Tower Air Inc.'),
#  (u'FFQ', u'Five Star Airlines'),
#  (u'FH', u'Frontier Horizon Inc.'),
#  (u'FI', u'Icelandair'),
#  (u'FJ', u'Air Pacific Ltd.'),
#  (u'FJ (1)', u'Air Pacific Ltd. (1)'),
#  (u'FL', u'AirTran Airways Corporation'),
#  (u'FL (1)', u'Frontier Airlines Inc. (1)'),
#  (u'FLA', u'Florida Air'),
#  (u'FLM', u'Flamenco Airways Inc.'),
#  (u'FLR', u'Flirite Inc.'),
#  (u'FNQ', u'Fine Airlines Inc.'),
#  (u'FOR', u'Ford-Aire Inc.'),
#  (u'FOS', u'Foster Aviation'),
#  (u'FP', u'TAG Aviation S.A.'),
#  (u'FQ', u'Air Aruba'),
#  (u'FRA', u'Freedom Air'),
#  (u'FRS', u'Four Star Aviation'),
#  (u'FRT', u'Frontier Commuter'),
#  (u'FRW', u'Farwest Airlines'),
#  (u'FS', u'Serv De Trans Aereos Fuegui'),
#  (u'FSA', u'F.S. Air Service'),
#  (u'FT', u'Flying Tiger Line Inc.'),
#  (u'FTI', u'Southern Airways'),
#  (u'FVA', u'Skycraft Inc.'),
#  (u'FW', u'Skybus Inc.'),
#  (u'FWA', u'Far West Airlines'),
#  (u'FX', u'Federal Express Corporation'),
#  (u'FYB', u'Flying Boat'),
#  (u'FYQ', u'Flying Group Lux S.A.'),
#  (u'G3', u'VRG Linhas Aereas S A'),
#  (u'G3 (1)', u'Aerochago S.A.'),
#  (u'G4', u'Allegiant Air'),
#  (u'G7', u'GoJet Airlines LLC d/b/a United Express'),
#  (u'GA', u'P.T. Garuda Indonesian Arwy'),
#  (u'GAL', u'Galena Air Service'),
#  (u'GAQ', u'Galaxy Airlines Inc.'),
#  (u'GAS', u'General Aviation Inc.'),
#  (u'GAT', u'Gulf Air Taxi'),
#  (u'GAV', u'Gromer Aviation Inc.'),
#  (u'GBA', u'Central States Airline'),
#  (u'GBQ', u'G5 Executive Ag'),
#  (u'GCA', u'Golden Carriage Aire'),
#  (u'GCH', u'Grand Canyon Helicopters'),
#  (u'GCQ', u'Glock Aviation GmbH'),
#  (u'GCQ (1)', u'General Air Cargo'),
#  (u'GCS', u'Midway Commuter'),
#  (u'GD', u'Transp. Aereos Ejecutivos'),
#  (u'GDW', u'Golden West Airlines Inc.'),
#  (u'GE', u'Lufthansa Cargo Airlines'),
#  (u'GF', u'Gulf Air Company'),
#  (u'GF (1)', u'Gulf Air Transport Inc.'),
#  (u'GFC', u'Gulf Flite Center'),
#  (u'GFQ', u'Gulf And Caribbean Cargo'),
#  (u'GG', u'Cargo 360, Inc.'),
#  (u'GG (1)', u'Tropical Airways Inc.'),
#  (u'GG (2)', u'Grenada Airways Ltd.'),
#  (u'GH', u'Ghana Airways Corporation'),
#  (u'GHA', u'Green Hills Aviation Ltd.'),
#  (u'GIQ', u'Global International Airways Corp.'),
#  (u'GJ', u'Eurofly S.p.A'),
#  (u'GJ (1)', u'Mexicargo'),
#  (u'GKQ', u'Laker Airways'),
#  (u'GL', u'Miami Air International'),
#  (u'GLW', u'Golden West Airlines Co.'),
#  (u'GM', u'Air America'),
#  (u'GMA', u'Green Mountain Airlines Ltd.'),
#  (u'GOF', u'Copper State Airlines'),
#  (u'GPA', u'GP Express Airlines'),
#  (u'GQ', u'Big Sky Airlines Inc.'),
#  (u'GR', u'Gemini Air Cargo Airways'),
#  (u'GRA', u'Gorda Aero Service'),
#  (u'GRD', u'Grand Canyon Airlines'),
#  (u'GRO', u'Isle Royale Seaplane Serv.'),
#  (u'GS', u'Air Foyle Limited'),
#  (u'GSA', u'Golden Gate Airlines Inc.'),
#  (u'GSC', u'GCS Air Service'),
#  (u'GSL', u'Golden South Airlines Inc.'),
#  (u'GSQ', u'Global Supply System'),
#  (u'GST', u'Golden State Airlines'),
#  (u'GU', u'Aviateca'),
#  (u'GUL', u'Gull Air Inc.'),
#  (u'GUN', u'Gunnel Aviation Inc.'),
#  (u'GV', u'Grant Aviation'),
#  (u'GW', u'SkyGreece Airlines S A'),
#  (u'GW (1)', u'Central American Airlines'),
#  (u'GWA', u'Great Western Aviation'),
#  (u'GWE', u'Ross Aviation Inc.'),
#  (u'GX', u'Air Ontario Limited'),
#  (u'GY', u'Guyana Airways Corporation'),
#  (u'H2', u'City Bird'),
#  (u'H5', u'Magadan Airlines'),
#  (u'H6', u'Hageland Aviation Service'),
#  (u'HA', u'Hawaiian Airlines Inc.'),
#  (u'HAQ', u'Hapag Lloyd Flug.'),
#  (u'HAR', u'Friendship Air Alaska'),
#  (u'HB', u'Homer Air'),
#  (u'HB (1)', u'Air Club International'),
#  (u'HBQ', u'Harris Air Services'),
#  (u'HCQ', u'Av Atlantic'),
#  (u'HEL', u'Helitrans'),
#  (u'HEP', u'Hub Express'),
#  (u'HER', u'Markair Express'),
#  (u'HET', u'Helitac Aviation'),
#  (u'HEU', u'Heussler Air Service Corp'),
#  (u'HFQ', u'Haiti Air Freight Intl'),
#  (u'HFS', u'Hensley Flying Service Inc.'),
#  (u'HIQ', u'Business Flights Ltd.'),
#  (u'HJ', u'Air Haiti S. A.'),
#  (u'HK', u'Time Air Sweden Ab'),
#  (u'HLQ', u'Heavylift Cargo Airlines Lt'),
#  (u'HMZ', u'Long Island Airlines'),
#  (u'HNS', u'Haines Airways'),
#  (u'HOL', u'Holiday Airlines Inc.'),
#  (u'HOQ', u'Holidair Airways'),
#  (u'HOR', u'Iowa Airlines'),
#  (u'HP', u'America West Airlines Inc. (Merged with US Airways 9/05. Stopped reporting 10/07.)'),
#  (u'HPZ', u'Pacific Coast Airlines'),
#  (u'HQ', u'Harmony Airways'),
#  (u'HQ (1)', u'Business Express'),
#  (u'HQQ', u'Harlequin Air Corporation'),
#  (u'HRA', u'Trans-National Airlines Haw'),
#  (u'HRG', u'Heritage Airlines'),
#  (u'HRQ', u'Tar Airlines'),
#  (u'HRZ', u'Allegheny Airlines'),
#  (u'HSV', u'Harbor Air Service'),
#  (u'HSZ', u'Scenic Airlines Inc.'),
#  (u'HU', u'Hainan Airlines Company Limited'),
#  (u'HUB', u'Skystream Airlines'),
#  (u'HVQ', u'Transavia Holland B. V.'),
#  (u'HWK', u'Hawking Corporation'),
#  (u'HX', u'Hong Kong Airlines Limited'),
#  (u'HX (1)', u'Guy-America Airways Inc.'),
#  (u'HY', u'Uzbekistan Airways'),
#  (u'HYA', u'Hyannis Aviation'),
#  (u'I4', u'Scott Air LLC dba Island Air Express'),
#  (u'IA', u'Iraqi Airways'),
#  (u'IB', u'Iberia Air Lines Of Spain'),
#  (u'ICF', u'Iowa City Flying Service'),
#  (u'ICH', u'Island Air Charters'),
#  (u'ICQ', u'Iscargo Hf'),
#  (u'IDQ', u'Intl Air Service Co. Ltd.'),
#  (u'IEX', u'Island Air Express'),
#  (u'IG', u'Airitaly S.P.A.'),
#  (u'IGA', u'Global Jet Austria, GmbH'),
#  (u'III', u'Idee Industries Inc.'),
#  (u'IJ', u'Great Wall Airlines Company Limited'),
#  (u'IKQ', u'Tradewinds Airways Ltd.'),
#  (u'IMP', u'Imperial Airlines Inc.'),
#  (u'IN', u'Aerlinte Eireann Teoranta'),
#  (u'INA', u'Inland Empire Airlines Inc.'),
#  (u'IND', u'Indiana Airways Inc. (Pa)'),
#  (u'INQ', u'Independent Air Inc.'),
#  (u'IOW', u'Iowa Airways'),
#  (u'IPI', u'Indo-Pacific International'),
#  (u'IPQ', u'Aruba Cargo'),
#  (u'IPS', u'Island Express'),
#  (u'IR', u'Iran National Airlines Corp'),
#  (u'IRQ', u'Interstate Airlines Inc.'),
#  (u'ISL', u'Island Airlines'),
#  (u'ITQ', u'Interamericana De Aviacion'),
#  (u'IW', u'Air Liberte Aka Aom Minerve'),
#  (u'IW (1)', u'Best Airlines Inc.'),
#  (u'IXQ', u'Inair'),
#  (u'J2', u'Azerbaijan Airlines CJSC'),
#  (u'J5', u'Kalinin Aviation LLC d/b/a Alaska Seaplanes'),
#  (u'J6', u'Larrys Flying Service'),
#  (u'J7', u'Valujet Airlines Inc.'),
#  (u'JAG', u'JetAlliance Flugbetriebs d/b/a JAF Airservice'),
#  (u'JAM', u'Sunbelt Airlines Inc.'),
#  (u'JAQ', u'Jamaica Air Freighters'),
#  (u'JB', u'Helijet International Inc.'),
#  (u'JCM', u'Air Chico'),
#  (u'JCQ', u'Jet Connection Businessflight Ag'),
#  (u'JCZ', u'Rocky Mountain Airways Inc.'),
#  (u'JD', u'Beijing Capital Airlines'),
#  (u'JD (1)', u'Japan Air System Co. Ltd.'),
#  (u'JER', u'Jer-Don Air'),
#  (u'JF', u'L.A.B. Flying Service Inc.'),
#  (u'JI', u'Jade Cargo International'),
#  (u'JI (1)', u'Midway Airlines Inc.'),
#  (u'JIQ', u'Jet Fleet Intl. Airlines'),
#  (u'JJ', u'Transportes Aeros Meridiona'),
#  (u'JK', u'Spanair S.A.'),
#  (u'JK (1)', u'Sunworld International Airways Inc.'),
#  (u'JKQ', u'Express One International Inc.'),
#  (u'JL', u'Japan Air Lines Co. Ltd.'),
#  (u'JM', u'Air Jamaica Limited'),
#  (u'JMA', u'Jim Air Inc.'),
#  (u'JN', u'Excel Airways'),
#  (u'JO', u'Jalways Co. Ltd.'),
#  (u'JQ', u'Jetstar Airways Pty Limited'),
#  (u'JR', u'Aero California'),
#  (u'JTA', u'Jetaire Airlines Inc.'),
#  (u'JU', u'Air Serbia'),
#  (u'JU (1)', u'Yugoslav Airlines'),
#  (u'JW', u'Arrow Air Inc.'),
#  (u'JX', u'Southeast Airlines'),
#  (u'JX (1)', u'Jes Air Ltd.'),
#  (u'JXQ', u'Allarco Developments Ltd.'),
#  (u'JZ', u'Japan Air Charter Co. Ltd.'),
#  (u'K2', u'Paklook Air, Inc d/b/a/ Airlift Alaska d/b/a/ Yute Commuter Service'),
#  (u'K3', u'Venture Travel LLC d/b/a Taquan Air Service'),
#  (u'K5', u'Seaport Airlines, Inc.'),
#  (u'K7', u'Arizona Express'),
#  (u'K8', u'Dutch Caribbean Airlines'),
#  (u'KA', u'Hong Kong Dragonair'),
#  (u'KAH', u'Kenmore Air Harbor'),
#  (u'KAI', u'Knight Airlines Inc.'),
#  (u'KAQ', u'Kalitta Air LLC'),
#  (u'KAT', u'Katmai Air'),
#  (u'KB', u'Haiti Air'),
#  (u'KD', u'Western Global'),
#  (u'KE', u'Korean Air Lines Co. Ltd.'),
#  (u'KEA', u'Keene Airways'),
#  (u'KEE', u'Key Airlines'),
#  (u'KET', u'Ketchikan Air Service'),
#  (u'KFS', u'King Flying Service'),
#  (u'KH', u'Aloha Air Cargo'),
#  (u'KI', u'Time Air Ltd.'),
#  (u'KIN', u'Golden Pacific Airlines'),
#  (u'KKQ', u'Transmeridian Air Cargo Ltd.'),
#  (u'KL', u'Klm Royal Dutch Airlines'),
#  (u'KLQ', u'Kalitta Charters II'),
#  (u'KM', u'Air Malta'),
#  (u'KN', u'Morris Air Corporation'),
#  (u'KO', u'Alaska Central Express'),
#  (u'KOD', u'Kodiak Airways Inc.'),
#  (u'KP', u'Kiwi International'),
#  (u'KQ', u'Kenya Airways PLC'),
#  (u'KR', u'Kitty Hawk Aircargo'),
#  (u'KR (1)', u'Kar-Air Oy'),
#  (u'KS', u'Peninsula Airways Inc.'),
#  (u'KTQ', u'Turks Air Ltd.'),
#  (u'KU', u'Kuwait Airways Corp.'),
#  (u'KV', u'Sky Regional Airlines Inc.'),
#  (u'KW', u'Carnival Air Lines Inc.'),
#  (u'KWQ', u'Kelowna Flightcraft Air Cha'),
#  (u'KWZ', u'Crown Air'),
#  (u'KX', u'Cayman Airways Limited'),
#  (u'KXZ', u'Chaparral Airlines Inc.'),
#  (u'KZ', u'Nippon Cargo Airlines'),
#  (u'L2', u'Lynden Air Cargo Airlines'),
#  (u'L3', u'Lynx Aviation d/b/a Frontier Airlines'),
#  (u'L7', u'Lan Colombia'),
#  (u'LA', u'Lan-Chile Airlines'),
#  (u'LAA', u'La Skycab Airline'),
#  (u'LAH', u'La Helicopter'),
#  (u'LAN', u'Lancer Aviation Inc.'),
#  (u'LAP', u'Lapsa'),
#  (u'LAR', u'Laredo Air'),
#  (u'LAS', u'Lake Union Air Service'),
#  (u'LAW', u'Lawrence Aviation'),
#  (u'LB', u'Lloyd Aereo Boliviano S. A.'),
#  (u'LBQ', u'Millon Air Inc.'),
#  (u'LC', u'Varig Logistica S/A'),
#  (u'LC (1)', u'Lineas Aereas Del Caribe'),
#  (u'LC (2)', u'Legend Airlines'),
#  (u'LCQ', u'Latcr'),
#  (u'LCT', u'Lake Coastal'),
#  (u'LDM', u'Lauda Motion GmbH'),
#  (u'LEQ', u'Le Point Air'),
#  (u'LEX', u"L'Express"),
#  (u'LF', u'CFM Inc d/b/a Contour Airlines d/b/a One Jet Shuttle'),
#  (u'LF (1)', u'Jettrain Airlines'),
#  (u'LG', u'Luxair'),
#  (u'LGQ', u'Lineas Aereas Allegro'),
#  (u'LH', u'Lufthansa German Airlines'),
#  (u'LHA', u'Havasu Airlines'),
#  (u'LIQ', u'Liat (1974) Limited'),
#  (u'LJ', u'Jin Air Co Ltd.'),
#  (u'LKN', u'Loken Aviation'),
#  (u'LLA', u'Lakeland Aviation'),
#  (u'LNQ', u'Aerolineas Latinas'),
#  (u'LO', u'Polskie Linie Lotnicze'),
#  (u'LOQ', u'Lorair Ltd.'),
#  (u'LOS', u'Aero Commuter'),
#  (u'LP', u'Lan Peru Airlines'),
#  (u'LP (1)', u'The Hawaii Express Inc.'),
#  (u'LR', u'Lacsa'),
#  (u'LRQ', u'Air Liberte'),
#  (u'LS', u'Jet2.com'),
#  (u'LSQ', u'Lineas Aereas Suramerican'),
#  (u'LSZ', u'Alaska Island Air Inc.'),
#  (u'LT', u'Luftransport-Unternehmen'),
#  (u'LU', u'Air Atlantic Dominicana'),
#  (u'LUQ', u'Lineas Aereas La-Tur Sa'),
#  (u'LV', u'OPENSKIES SAS'),
#  (u'LVA', u'Las Vegas Airlines'),
#  (u'LW', u'Pacific Wings Airlines'),
#  (u'LX', u'Swiss International Airlines'),
#  (u'LXQ', u'Luxaviation Germany GmbH'),
#  (u'LXQ (1)', u'Translux Intl Airlines'),
#  (u'LY', u'El Al Israel Airlines Ltd.'),
#  (u'LZ', u'Balkan Bulgarian Airlines'),
#  (u'LZQ', u'Leisure International Airways Ltd.'),
#  (u'M3', u'ABSA-Aerolinhas Brasileiras'),
#  (u'M6', u'Amerijet International'),
#  (u'M7', u'Aerotransportes Mas De Crga'),
#  (u'MA', u'Malev Hungarian Airlines'),
#  (u'MAA', u'Maui Airlines'),
#  (u'MAC', u'Mackey International Inc.'),
#  (u'MAE', u'Mid-Atlantic Exp. Airlines'),
#  (u'MAG', u'Magum Airlines'),
#  (u'MAI', u'The Maui Commuter'),
#  (u'MAQ', u'Millardair Limited'),
#  (u'MAR', u"Marshall's Air Inc."),
#  (u'MAV', u'Maverick Airways'),
#  (u'MAX', u'Maxair Inc.'),
#  (u'MB', u'Samoa Airlines Inc.'),
#  (u'MC', u'Transtar Airlines Corp.'),
#  (u'MCO', u'Mid Continental Airlines In'),
#  (u'MDC', u'Midcontinent Airlines'),
#  (u'MDU', u'Metro Airlines'),
#  (u'ME', u'Middle East Airlines S.A.L.'),
#  (u'MEA', u'Manhattan Express'),
#  (u'MET', u'Metroplex Airlines'),
#  (u'MEX', u'Metro Express 11'),
#  (u'MF', u'Xiamen Airlines Co., Ltd.'),
#  (u'MG', u'Champion Air'),
#  (u'MGQ', u'Montana Austria Flugetrieb'),
#  (u'MH', u'Malaysian Airline System'),
#  (u'MHK', u'Mohawk Airlines'),
#  (u'MHO', u'Mahalo Air'),
#  (u'MIN', u'Minuteman Aviation Inc.'),
#  (u'MIS', u'Midstate Airlines Inc.'),
#  (u'MIY', u'Midway Aviation Inc.'),
#  (u'MJ', u'Lapa-Lineas Aereas Privadas'),
#  (u'MKQ', u'Airmark Corporation'),
#  (u'ML', u'Aero Costa Rica'),
#  (u'ML (1)', u'Midway Airlines Inc. (1)'),
#  (u'MLL', u'Miller Air Transportersinc'),
#  (u'MLX', u'Merlin Express'),
#  (u'MM', u'Euro Atlantic Airways'),
#  (u'MM (1)', u'Sociedad Aeronautica De Med'),
#  (u'MMH', u'Ocean Airways Inc.'),
#  (u'MNA', u'M & N Aviation'),
#  (u'MNZ', u'Cumberland Airlines'),
#  (u'MOQ', u'Morningstar Air Express'),
#  (u'MP', u'Martinair Holland N.V.'),
#  (u'MPA', u'Mid Pacific Airlines Inc.'),
#  (u'MPC', u'Mid Pacific Air Corp.'),
#  (u'MQ', u'Envoy Air'),
#  (u'MRC', u'Marco Island Airways Inc.'),
#  (u'MRR', u'Merrimack Aviation Inc.'),
#  (u'MS', u'Egyptair'),
#  (u'MST', u'Midwest Aviation'),
#  (u'MT', u'Thomas Cook Airlines Uk Ltd.'),
#  (u'MT (1)', u'Flying Colours Airlines Ltd.'),
#  (u'MTA', u'Arkansas Traveler Airline'),
#  (u'MTR', u'Metroflight Airlines'),
#  (u'MTV', u'Mst Aviation'),
#  (u'MTX', u'Mountain Air Express'),
#  (u'MU', u'China Eastern Airlines'),
#  (u'MU (1)', u'Mcclain Airlines Inc.'),
#  (u'MUA', u"Manu'a Air Transport"),
#  (u'MUQ', u'Aerolineas Mundo'),
#  (u'MVA', u'Mississippi Valley Airlines'),
#  (u'MW', u'Mokulele Flight Services, Inc.'),
#  (u'MWA', u'Mountain West Airlines'),
#  (u'MX', u'Compania Mexicana De Aviaci'),
#  (u'MY', u'MAXjet'),
#  (u'MYQ', u'Lineas Aereas Mayas (Lamsa)'),
#  (u'MZ', u'P.N. Merpati Nusantara Air.'),
#  (u'N5', u'Skagway Air Service'),
#  (u'N5 (1)', u'Nations Air Express Inc.'),
#  (u'N6', u'Aero Continente'),
#  (u'N7', u'National Airlines'),
#  (u'N8', u'National Air Cargo Group Inc d/ba National Airlines'),
#  (u'NA', u'North American Airlines'),
#  ...]

# %%
# %%sql
# SELECT IATA_CODE_Reporting_Airline, Reporting_Airline
# from ontime
# group by IATA_CODE_Reporting_Airline
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'9E', u'9E'),
#  (u'AA', u'AA'),
#  (u'AS', u'AS'),
#  (u'B6', u'B6'),
#  (u'DL', u'DL'),
#  (u'EV', u'EV'),
#  (u'F9', u'F9'),
#  (u'G4', u'G4'),
#  (u'HA', u'HA'),
#  (u'MQ', u'MQ'),
#  (u'NK', u'NK'),
#  (u'OH', u'OH'),
#  (u'OO', u'OO'),
#  (u'UA', u'UA'),
#  (u'VX', u'VX'),
#  (u'WN', u'WN'),
#  (u'YV', u'YV'),
#  (u'YX', u'YX')]

# %% [markdown]
# ## PREGUNTA 1:
# #¿Cuáles son las cinco aerolíneas que han cancelado - proporcionalmente - menos vuelos?

# %%
# %%sql
#
# SELECT (COUNT(*)*1.0*100)/Cancelados as Porcentaje, Reporting_Airline
# FROM ontime,
# (
#     SELECT COUNT(*) as Cancelados
#     FROM ontime
#     WHERE Cancelled = 1 and CancellationCode = "A"
# )
# WHERE Cancelled = 1 and CancellationCode = "A"
# GROUP BY Reporting_Airline
# ORDER BY Porcentaje ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(0.6811026151770224, u'9E'),
#  (0.8524491850328771, u'G4'),
#  (0.9274133093448136, u'VX'),
#  (0.9702499518087773, u'HA'),
#  (2.972862986999079, u'OO'),
#  (3.277003148493221, u'UA'),
#  (3.5040373535522287, u'MQ'),
#  (3.529739339030607, u'AS'),
#  (3.8403049968943432, u'F9'),
#  (4.03306988798218, u'YX'),
#  (4.954057700957399, u'YV'),
#  (5.24748870183555, u'NK'),
#  (5.620167491272034, u'EV'),
#  (6.986656385872475, u'B6'),
#  (7.340058686200176, u'DL'),
#  (9.768896313906916, u'OH'),
#  (14.819336460408234, u'AA'),
#  (20.675105485232066, u'WN')]

# %% [markdown]
# # PREGUNTA 2:
# ¿Cuáles son las cinco aerolíneas que tienen la mayor cantidad de estados como destino?

# %%
# %%sql
# SELECT unique_carriers.Description as aerolinea, COUNT(DISTINCT DestStateNm) as cantidad_estados
# FROM ontime
# INNER JOIN unique_carriers ON IATA_CODE_Reporting_Airline = code
# GROUP BY IATA_CODE_Reporting_Airline
# ORDER BY COUNT(DISTINCT DestStateNm) DESC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'Delta Air Lines Inc.', 51),
#  (u'SkyWest Airlines Inc.', 48),
#  (u'American Airlines Inc.', 46),
#  (u'United Air Lines Inc.', 46),
#  (u'Allegiant Air', 44),
#  (u'Frontier Airlines Inc.', 42),
#  (u'ExpressJet Airlines Inc.', 41),
#  (u'Southwest Airlines Co.', 41),
#  (u'Mesa Airlines Inc.', 41),
#  (u'Envoy Air', 39),
#  (u'Republic Airline', 39),
#  (u'Endeavor Air Inc.', 37),
#  (u'PSA Airlines Inc.', 33),
#  (u'JetBlue Airways', 32),
#  (u'Alaska Airlines Inc.', 31),
#  (u'Spirit Air Lines', 27),
#  (u'Virgin America', 20),
#  (u'Hawaiian Airlines Inc.', 8)]

# %% [markdown]
# # PREGUNTA 3:
#
# ¿Cuáles son las cinco aerolíneas que llegan ante de lo previsto (cuando salieron a tiempo)?
#
#
# en el delay solo hay que tomar en cuenta el delay por culpa de la aerolinea

# %%
# %%sql
# SELECT DISTINCT unique_carriers.Description as aerolinea, SUM(CASE WHEN "Year"="2017" THEN 1 ELSE 0 END) as "CantidadVuelos2017", SUM(CASE WHEN "Year"="2018" THEN 1 ELSE 0 END) as "CantidadVuelos2018"
# FROM ontime
# INNER JOIN unique_carriers ON unique_carriers.Code = ontime.Reporting_Airline
# WHERE DepDelay = 0 and ArrDelay < 0
# GROUP BY Reporting_Airline
# ORDER BY ("2017"+"2018") DESC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'Southwest Airlines Co.', 76667, 77946),
#  (u'Delta Air Lines Inc.', 46464, 42483),
#  (u'American Airlines Inc.', 25723, 23338),
#  (u'United Air Lines Inc.', 19252, 15319),
#  (u'SkyWest Airlines Inc.', 13086, 12903),
#  (u'JetBlue Airways', 6854, 5637),
#  (u'ExpressJet Airlines Inc.', 6004, 2943),
#  (u'PSA Airlines Inc.', 0, 8716),
#  (u'Spirit Air Lines', 3462, 4642),
#  (u'Alaska Airlines Inc.', 3457, 4254),
#  (u'Envoy Air', 0, 6123),
#  (u'Mesa Airlines Inc.', 0, 5564),
#  (u'Republic Airline', 0, 5554),
#  (u'Frontier Airlines Inc.', 2996, 2519),
#  (u'Allegiant Air', 0, 5051),
#  (u'Hawaiian Airlines Inc.', 1419, 1433),
#  (u'Virgin America', 1529, 336),
#  (u'Endeavor Air Inc.', 0, 998)]

# %% [markdown]
# # PREGUNTA 4:
#
# ¿Qué 5 aerolíneas tienen la menor aportación porcentual al total de tiempos de retraso de llegada de todos los vuelos?
#
# en el delay solo hay que tomar en cuenta el delay por culpa de la aerolinea

# %%
# %%sql
#
# SELECT (SUM(CarrierDelay)*1.0*100)/(RetrasosAerolineas) as PorcentajeRetraso, U.Description
# FROM ontime,
# (
#     SELECT SUM(CarrierDelay) as RetrasosAerolineas
#     FROM ontime
#     WHERE CarrierDelay >0
# )
# JOIN unique_carriers U ON U.code = ontime.Reporting_Airline
# WHERE CarrierDelay >0
# GROUP BY Reporting_Airline
# ORDER BY PorcentajeRetraso ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(0.5445618152957644, u'Virgin America'),
#  (0.9832625560267009, u'Hawaiian Airlines Inc.'),
#  (1.227505074985979, u'Allegiant Air'),
#  (1.5959969644703726, u'Envoy Air'),
#  (1.6567327889102197, u'Republic Airline'),
#  (1.787774850853501, u'Endeavor Air Inc.'),
#  (1.861961045364444, u'Spirit Air Lines'),
#  (1.9666446315504957, u'Alaska Airlines Inc.'),
#  (2.0880631606537037, u'PSA Airlines Inc.'),
#  (2.1137089460764105, u'Mesa Airlines Inc.'),
#  (2.184267502518154, u'Frontier Airlines Inc.'),
#  (7.187105758575529, u'JetBlue Airways'),
#  (7.272814517935926, u'ExpressJet Airlines Inc.'),
#  (7.637877968512942, u'United Air Lines Inc.'),
#  (13.539841481291004, u'Delta Air Lines Inc.'),
#  (14.941926915022723, u'American Airlines Inc.'),
#  (15.163542622522922, u'SkyWest Airlines Inc.'),
#  (16.246411399433207, u'Southwest Airlines Co.')]

# %% [markdown]
# # PREGUNTA 5:
#
# ¿Cuál es la frecuencia de vuelos para las aerolíneas que tienen menor cantidad de vuelos  cancelados?
#
# Frecuencia: cuantos vuelos tienen en determinado tiempo

# %%
# %%sql
#
#  SELECT
#     Reporting_Airline,
#     SUM(CASE WHEN Cancelled = 1 AND CancellationCode = 'A' THEN 1 ELSE 0 END) AS Cancelado,
#     (SUM(CASE WHEN Quarter = 1 THEN 1 ELSE 0 END) +
#     SUM(CASE WHEN Quarter = 2 THEN 1 ELSE 0 END) +
#     SUM(CASE WHEN Quarter = 3 THEN 1 ELSE 0 END) +
#     SUM(CASE WHEN Quarter = 4 THEN 1 ELSE 0 END))/4 as CantVuelosPorCuarto
# FROM ontime ontime_externo
# GROUP BY Reporting_Airline
# ORDER BY Cancelado ASC;
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'9E', 318, 56306),
#  (u'G4', 398, 22137),
#  (u'VX', 433, 22332),
#  (u'HA', 453, 39372),
#  (u'OO', 1388, 356783),
#  (u'UA', 1530, 290752),
#  (u'MQ', 1636, 67601),
#  (u'AS', 1648, 103008),
#  (u'F9', 1793, 53545),
#  (u'YX', 1883, 72612),
#  (u'YV', 2313, 49140),
#  (u'NK', 2450, 79855),
#  (u'EV', 2624, 133335),
#  (u'B6', 3262, 145444),
#  (u'DL', 3427, 452897),
#  (u'OH', 4561, 63849),
#  (u'AA', 6919, 437009),
#  (u'WN', 9653, 647093)]

# %% [markdown]
# # PREGUNTA 6:
# ¿Cuál es la proporción o razón de distancia total recorrida (de todas las aeronaves) respecto a la cantidad de vuelos?
#
# no solo tienen muchos vuelos si no que tambien al tener grandes distancias los pilotos tienen mas experiencia

# %%
# %%sql
# SELECT Reporting_Airline as Aerolinea, (SUM(Distance)/COUNT(*)) as Razon
# FROM ontime
# GROUP BY Reporting_Airline
# ORDER BY Razon ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'OH', 382.9295172986264),
#  (u'MQ', 433.2349253896932),
#  (u'EV', 465.34392320096),
#  (u'OO', 473.3308645158759),
#  (u'9E', 475.9989166485368),
#  (u'YV', 550.173070074582),
#  (u'YX', 594.3277695721481),
#  (u'HA', 644.162075840699),
#  (u'WN', 747.4383230076666),
#  (u'DL', 879.1340568230119),
#  (u'G4', 881.8799647652712),
#  (u'NK', 1018.5176005409771),
#  (u'AA', 1021.3956588994735),
#  (u'B6', 1053.674028581349),
#  (u'F9', 1059.9900551402786),
#  (u'UA', 1185.1799444372314),
#  (u'AS', 1277.56666092279),
#  (u'VX', 1482.0319720580333)]

# %%
# %%sql

# %% [markdown]
# # PREGUNTA 7:
#
# ¿Cuáles 5 aerolíneas tienen predichas el mayor crecimiento en operaciones?

# %%
# %%sql
#
# SELECT
#     Reporting_Airline,
#     ((((SUM(CASE WHEN Quarter = 2 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END) - SUM(CASE WHEN Quarter = 1 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END))*1.0/SUM(CASE WHEN Quarter = 1 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END)) +
#     ((SUM(CASE WHEN Quarter = 3 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END) - SUM(CASE WHEN Quarter = 2 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END))*1.0/SUM(CASE WHEN Quarter = 2 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END)) +
#     ((SUM(CASE WHEN Quarter = 4 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END) - SUM(CASE WHEN Quarter = 3 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END))*1.0/SUM(CASE WHEN Quarter = 3 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END)) +
#     ((SUM(CASE WHEN Quarter = 1 and "Year" = '2018' NOT NULL THEN 1 ELSE 0 END) - SUM(CASE WHEN Quarter = 4 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END))*1.0/SUM(CASE WHEN Quarter = 4 and "Year" = '2017' NOT NULL THEN 1 ELSE 0 END)) +
#     ((SUM(CASE WHEN Quarter = 2 AND "Year" = '2018' NOT NULL THEN 1 ELSE 0 END) - SUM(CASE WHEN Quarter = 1 AND "Year" = '2018' NOT NULL THEN 1 ELSE 0 END))*1.0/SUM(CASE WHEN Quarter = 1 AND "Year" = '2018' NOT NULL THEN 1 ELSE 0 END)) +
#     ((SUM(CASE WHEN Quarter = 3 AND "Year" = '2018' NOT NULL THEN 1 ELSE 0 END) - SUM(CASE WHEN Quarter = 2 AND "Year" = '2018' NOT NULL THEN 1 ELSE 0 END))*1.0/SUM(CASE WHEN Quarter = 2 AND "Year" = '2018' NOT NULL THEN 1 ELSE 0 END)) +
#     ((SUM(CASE WHEN Quarter = 4 AND "Year" = '2018' NOT NULL THEN 1 ELSE 0 END) - SUM(CASE WHEN Quarter = 3 AND "Year" = '2018' NOT NULL THEN 1 ELSE 0 END))*1.0/SUM(CASE WHEN Quarter = 3 AND "Year" = '2018' NOT NULL THEN 1 ELSE 0 END)))/4)*100 as CrecimientoPromedio
# FROM ontime ontime_externo
# GROUP BY Reporting_Airline
# ORDER BY CrecimientoPromedio DESC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'AS', 2.6929434891597603),
#  (u'VX', 0.27346852280272643),
#  (u'YV', -0.020696211931416075),
#  (u'F9', -0.0432356223712467),
#  (u'UA', -0.1111756402406884),
#  (u'OO', -1.1680427872755208),
#  (u'MQ', -1.5693454927665411),
#  (u'HA', -1.7208141264798436),
#  (u'DL', -1.7701393679953208),
#  (u'9E', -2.0021387164364857),
#  (u'NK', -2.3338204750301106),
#  (u'G4', -2.8362868994137576),
#  (u'OH', -2.8458865278565044),
#  (u'YX', -2.856279456778203),
#  (u'WN', -2.8886786561556126),
#  (u'AA', -3.0201460634940593),
#  (u'B6', -3.368163112377756),
#  (u'EV', -6.111606147574725)]

# %% [markdown]
# # PREGUNTA 8:
#
# ¿Cuáles aerolíneas tienen la mayor cantidad de vuelos en los estados más poblados?

# %%
# %%sql
# SELECT Reporting_Airline, COUNT(DISTINCT origen) as Estados, COUNT(Reporting_Airline) as CantidadDeVuelos
# FROM ontime o
# JOIN (
#     SELECT COUNT(DISTINCT DestAirportID) as CantAeropuertos, DestStateNm as origen
#     FROM ontime
#     GROUP BY DestStateNm
#     ORDER BY CantAeropuertos DESC
#     LIMIT 10
# ) tabla ON o.DestStateNm = tabla.origen
# GROUP BY Reporting_Airline
# ORDER BY Estados DESC, CantidadDeVuelos DESC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'AA', 10, 1191898),
#  (u'UA', 10, 804219),
#  (u'OO', 10, 746477),
#  (u'DL', 10, 688037),
#  (u'B6', 10, 366176),
#  (u'AS', 10, 194486),
#  (u'WN', 9, 1446153),
#  (u'NK', 9, 181164),
#  (u'YV', 9, 128195),
#  (u'F9', 9, 128004),
#  (u'G4', 9, 41770),
#  (u'EV', 8, 255295),
#  (u'MQ', 8, 185105),
#  (u'YX', 8, 157456),
#  (u'9E', 8, 113051),
#  (u'VX', 8, 70615),
#  (u'OH', 7, 159681),
#  (u'HA', 2, 10606)]

# %%
# %%sql
#     SELECT COUNT(DISTINCT DestAirportID) as CantAeropuertos, DestStateNm as origen
#     FROM ontime
#     GROUP BY DestStateNm
#     ORDER BY CantAeropuertos DESC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(25, u'Texas'),
#  (22, u'California'),
#  (20, u'Florida'),
#  (19, u'Alaska'),
#  (15, u'Michigan'),
#  (15, u'New York'),
#  (11, u'Colorado'),
#  (10, u'Illinois'),
#  (10, u'North Carolina'),
#  (9, u'Virginia'),
#  (8, u'Minnesota'),
#  (8, u'Montana'),
#  (8, u'Pennsylvania'),
#  (8, u'Wisconsin'),
#  (7, u'Arizona'),
#  (7, u'Georgia'),
#  (7, u'Louisiana'),
#  (7, u'Missouri'),
#  (7, u'North Dakota'),
#  (7, u'Ohio'),
#  (7, u'Utah'),
#  (7, u'Wyoming'),
#  (6, u'Idaho'),
#  (6, u'Kansas'),
#  (6, u'Nebraska'),
#  (6, u'South Carolina'),
#  (5, u'Alabama'),
#  (5, u'Hawaii'),
#  (5, u'Iowa'),
#  (5, u'Kentucky'),
#  (5, u'Massachusetts'),
#  (5, u'Mississippi'),
#  (5, u'Oregon'),
#  (5, u'Tennessee'),
#  (4, u'Arkansas'),
#  (4, u'Indiana'),
#  (4, u'New Mexico'),
#  (4, u'Oklahoma'),
#  (4, u'Washington'),
#  (4, u'West Virginia'),
#  (3, u'Nevada'),
#  (3, u'New Jersey'),
#  (3, u'Puerto Rico'),
#  (3, u'South Dakota'),
#  (3, u'U.S. Pacific Trust Territories and Possessions'),
#  (2, u'Connecticut'),
#  (2, u'Maine'),
#  (2, u'Maryland'),
#  (2, u'New Hampshire'),
#  (2, u'U.S. Virgin Islands'),
#  (1, u'Rhode Island'),
#  (1, u'Vermont')]

# %% [markdown]
# # PREGUNTA 9:
#
# De las aerolíneas que tienen menor tiempo de retraso y llegan antes, ¿Cuál es su velocidad promedio en sus vuelos?

# %%
# %%sql
#
# SELECT Reporting_Airline, RetrasosAerolineas, SUM(Distance)/(SUM(AirTime)/60) as Velocidad
# FROM ontime
# JOIN (
#     SELECT SUM(arrDelay) as RetrasosAerolineas, Reporting_Airline as aero
#     FROM ontime
#     WHERE arrDelay>0
#     GROUP BY Reporting_Airline
#     ORDER BY RetrasosAerolineas ASC
# ) Delays ON ontime.Reporting_Airline = Delays.aero
# GROUP BY Reporting_Airline
# ORDER BY RetrasosAerolineas ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'HA', 934952.0, 448.98368819452634),
#  (u'VX', 1490442.0, 474.84763922943716),
#  (u'G4', 1560343.0, 452.8840934813209),
#  (u'YV', 3010744.0, 413.06485486298476),
#  (u'9E', 3319270.0, 396.6535582788832),
#  (u'MQ', 3414205.0, 390.41066992639617),
#  (u'YX', 3642530.0, 408.2470841494916),
#  (u'AS', 3722874.0, 461.94037884666665),
#  (u'OH', 3766518.0, 374.02874349360866),
#  (u'F9', 4039137.0, 459.75034167937565),
#  (u'NK', 4664065.0, 459.49640974141397),
#  (u'EV', 9170694.0, 393.263974232681),
#  (u'B6', 11365918.0, 453.70896590619765),
#  (u'UA', 15558135.0, 465.27242019913103),
#  (u'DL', 18638450.0, 445.8065020975332),
#  (u'OO', 21762259.0, 392.21273969488465),
#  (u'AA', 22526555.0, 451.92821060535823),
#  (u'WN', 28443506.0, 439.39811800317295)]

# %% [markdown]
# # PREGUNTA 10:
#
# ¿Cuáles aerolíneas son las más eficientes en sus vuelos respecto a la distancia que recorren?
#
#
# Para las aerolineas con los vuelos que recorrieron las distancias mayores, ¿Cual es su eficiencia (tiempo en el aire) respecto a la distancia que recorren?
#
# Es decir, verificar el tiempo en aire que tiene (en promedio) los vuelos de cada aerolínea y, dependiendo de la categoria de distancia que recorrieron los vuelos (los vuelos son clasificados por la distancia que recorreron) ordenarlos

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas,
# SUM(CASE WHEN DistanceGroup = 1 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion1,
# SUM(CASE WHEN DistanceGroup = 2 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion2,
# SUM(CASE WHEN DistanceGroup = 3 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion3,
# SUM(CASE WHEN DistanceGroup = 4 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion4,
# SUM(CASE WHEN DistanceGroup = 5 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion5,
# SUM(CASE WHEN DistanceGroup = 6 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion6,
# SUM(CASE WHEN DistanceGroup = 7 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion7,
# SUM(CASE WHEN DistanceGroup = 8 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion8,
# SUM(CASE WHEN DistanceGroup = 9 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion9,
# SUM(CASE WHEN DistanceGroup = 10 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion10,
# SUM(CASE WHEN DistanceGroup = 11 THEN AirTime ELSE 0 END) as TiempoEnAireClasificacion11
# FROM ontime
# GROUP BY Reporting_Airline
# ORDER BY (TiempoEnAireClasificacion1 + TiempoEnAireClasificacion2 + TiempoEnAireClasificacion3 +
# TiempoEnAireClasificacion4 + TiempoEnAireClasificacion5 + TiempoEnAireClasificacion6 +
# TiempoEnAireClasificacion7 + TiempoEnAireClasificacion8 + TiempoEnAireClasificacion9 +
# TiempoEnAireClasificacion10 + TiempoEnAireClasificacion11) ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'G4', 105.0, 585471.0, 2000750.0, 3001390.0, 3085820.0, 940982.0, 609886.0, 121235.0, 0, 0, 0),
#  (u'HA', 3331268.0, 62080.0, 0, 0, 0, 0, 0, 0, 0, 3423027.0, 6740616.0),
#  (u'OH', 2895698.0, 6301555.0, 4514690.0, 1894394.0, 66073.0, 16010.0, 0, 0, 0, 0, 0),
#  (u'YV', 972885.0, 4565296.0, 4789459.0, 2199722.0, 2122559.0, 984255.0, 74222.0, 0, 0, 0, 0),
#  (u'9E', 1951695.0, 4805198.0, 4652937.0, 2703585.0, 1843842.0, 259586.0, 0, 0, 0, 0, 0),
#  (u'VX', 159349.0, 1347185.0, 538790.0, 638676.0, 889991.0, 719215.0, 777581.0, 695367.0, 505506.0, 5965932.0, 4490336.0),
#  (u'MQ', 2291606.0, 6300937.0, 4710183.0, 3725112.0, 805700.0, 170410.0, 0, 0, 0, 0, 0),
#  (u'YX', 1935157.0, 5593907.0, 6071947.0, 5061868.0, 4388133.0, 1927236.0, 392137.0, 0, 0, 0, 0),
#  (u'F9', 302.0, 1054636.0, 2853378.0, 7405083.0, 6110223.0, 3284985.0, 4806881.0, 1584823.0, 2250867.0, 277476.0, 0),
#  (u'EV', 3756796.0, 12287878.0, 12712179.0, 7436186.0, 1672422.0, 178.0, 0, 0, 0, 0.0, 0),
#  (u'NK', 313184.0, 1916305.0, 4434689.0, 10490420.0, 10552847.0, 3301698.0, 4514995.0, 2212088.0, 2347262.0, 2308462.0, 89809.0),
#  (u'AS', 955211.0, 1497224.0, 6537352.0, 10553774.0, 4402636.0, 5279107.0, 5605352.0, 3203467.0, 1634584.0, 15019104.0, 13684600.0),
#  (u'B6', 1872557.0, 6733801.0, 4190359.0, 11570283.0, 23306378.0, 770228.0, 5892567.0, 1557627.0, 3334698.0, 11595220.0, 10242042.0),
#  (u'OO', 13646281.0, 28729456.0, 26881864.0, 15091943.0, 8084995.0, 7319361.0, 3502888.0, 80993.0, 0, 0, 0),
#  (u'UA', 2488227.0, 8729258.0, 15417023.0, 26209918.0, 17430939.0, 16287976.0, 24048868.0, 10826525.0, 7705144.0, 28099901.0, 20506917.0),
#  (u'DL', 5931808.0, 22702091.0, 41534583.0, 29007196.0, 23049872.0, 12865391.0, 23161873.0, 18261609.0, 15741731.0, 10017000.0, 12075061.0),
#  (u'AA', 5915986.0, 13278483.0, 31096731.0, 33515835.0, 41591695.0, 23111888.0, 20328392.0, 14267029.0, 14938066.0, 21890538.0, 17107835.0),
#  (u'WN', 7474725.0, 48854894.0, 41017743.0, 55668770.0, 38675487.0, 20250947.0, 24376926.0, 16696183.0, 6179544.0, 4798617.0, 183230.0)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup =1
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'G4', 105.0, 1),
#  (u'F9', 302.0, 1),
#  (u'VX', 159349.0, 1),
#  (u'NK', 313184.0, 1),
#  (u'AS', 955211.0, 1),
#  (u'YV', 972885.0, 1),
#  (u'B6', 1872557.0, 1),
#  (u'YX', 1935157.0, 1),
#  (u'9E', 1951695.0, 1),
#  (u'MQ', 2291606.0, 1),
#  (u'UA', 2488227.0, 1),
#  (u'OH', 2895698.0, 1),
#  (u'HA', 3331268.0, 1),
#  (u'EV', 3756796.0, 1),
#  (u'AA', 5915986.0, 1),
#  (u'DL', 5931808.0, 1),
#  (u'WN', 7474725.0, 1),
#  (u'OO', 13646281.0, 1)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup =2
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'HA', 62080.0, 2),
#  (u'G4', 585471.0, 2),
#  (u'F9', 1054636.0, 2),
#  (u'VX', 1347185.0, 2),
#  (u'AS', 1497224.0, 2),
#  (u'NK', 1916305.0, 2),
#  (u'YV', 4565296.0, 2),
#  (u'9E', 4805198.0, 2),
#  (u'YX', 5593907.0, 2),
#  (u'MQ', 6300937.0, 2),
#  (u'OH', 6301555.0, 2),
#  (u'B6', 6733801.0, 2),
#  (u'UA', 8729258.0, 2),
#  (u'EV', 12287878.0, 2),
#  (u'AA', 13278483.0, 2),
#  (u'DL', 22702091.0, 2),
#  (u'OO', 28729456.0, 2),
#  (u'WN', 48854894.0, 2)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup =3
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'VX', 538790.0, 3),
#  (u'G4', 2000750.0, 3),
#  (u'F9', 2853378.0, 3),
#  (u'B6', 4190359.0, 3),
#  (u'NK', 4434689.0, 3),
#  (u'OH', 4514690.0, 3),
#  (u'9E', 4652937.0, 3),
#  (u'MQ', 4710183.0, 3),
#  (u'YV', 4789459.0, 3),
#  (u'YX', 6071947.0, 3),
#  (u'AS', 6537352.0, 3),
#  (u'EV', 12712179.0, 3),
#  (u'UA', 15417023.0, 3),
#  (u'OO', 26881864.0, 3),
#  (u'AA', 31096731.0, 3),
#  (u'WN', 41017743.0, 3),
#  (u'DL', 41534583.0, 3)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup =4
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'VX', 638676.0, 4),
#  (u'OH', 1894394.0, 4),
#  (u'YV', 2199722.0, 4),
#  (u'9E', 2703585.0, 4),
#  (u'G4', 3001390.0, 4),
#  (u'MQ', 3725112.0, 4),
#  (u'YX', 5061868.0, 4),
#  (u'F9', 7405083.0, 4),
#  (u'EV', 7436186.0, 4),
#  (u'NK', 10490420.0, 4),
#  (u'AS', 10553774.0, 4),
#  (u'B6', 11570283.0, 4),
#  (u'OO', 15091943.0, 4),
#  (u'UA', 26209918.0, 4),
#  (u'DL', 29007196.0, 4),
#  (u'AA', 33515835.0, 4),
#  (u'WN', 55668770.0, 4)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup =5
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'OH', 66073.0, 5),
#  (u'MQ', 805700.0, 5),
#  (u'VX', 889991.0, 5),
#  (u'EV', 1672422.0, 5),
#  (u'9E', 1843842.0, 5),
#  (u'YV', 2122559.0, 5),
#  (u'G4', 3085820.0, 5),
#  (u'YX', 4388133.0, 5),
#  (u'AS', 4402636.0, 5),
#  (u'F9', 6110223.0, 5),
#  (u'OO', 8084995.0, 5),
#  (u'NK', 10552847.0, 5),
#  (u'UA', 17430939.0, 5),
#  (u'DL', 23049872.0, 5),
#  (u'B6', 23306378.0, 5),
#  (u'WN', 38675487.0, 5),
#  (u'AA', 41591695.0, 5)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup = 6
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'EV', 178.0, 6),
#  (u'OH', 16010.0, 6),
#  (u'MQ', 170410.0, 6),
#  (u'9E', 259586.0, 6),
#  (u'VX', 719215.0, 6),
#  (u'B6', 770228.0, 6),
#  (u'G4', 940982.0, 6),
#  (u'YV', 984255.0, 6),
#  (u'YX', 1927236.0, 6),
#  (u'F9', 3284985.0, 6),
#  (u'NK', 3301698.0, 6),
#  (u'AS', 5279107.0, 6),
#  (u'OO', 7319361.0, 6),
#  (u'DL', 12865391.0, 6),
#  (u'UA', 16287976.0, 6),
#  (u'WN', 20250947.0, 6),
#  (u'AA', 23111888.0, 6)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup = 7
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'YV', 74222.0, 7),
#  (u'YX', 392137.0, 7),
#  (u'G4', 609886.0, 7),
#  (u'VX', 777581.0, 7),
#  (u'OO', 3502888.0, 7),
#  (u'NK', 4514995.0, 7),
#  (u'F9', 4806881.0, 7),
#  (u'AS', 5605352.0, 7),
#  (u'B6', 5892567.0, 7),
#  (u'AA', 20328392.0, 7),
#  (u'DL', 23161873.0, 7),
#  (u'UA', 24048868.0, 7),
#  (u'WN', 24376926.0, 7)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup =8
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'OO', 80993.0, 8),
#  (u'G4', 121235.0, 8),
#  (u'VX', 695367.0, 8),
#  (u'B6', 1557627.0, 8),
#  (u'F9', 1584823.0, 8),
#  (u'NK', 2212088.0, 8),
#  (u'AS', 3203467.0, 8),
#  (u'UA', 10826525.0, 8),
#  (u'AA', 14267029.0, 8),
#  (u'WN', 16696183.0, 8),
#  (u'DL', 18261609.0, 8)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup =9
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'VX', 505506.0, 9),
#  (u'AS', 1634584.0, 9),
#  (u'F9', 2250867.0, 9),
#  (u'NK', 2347262.0, 9),
#  (u'B6', 3334698.0, 9),
#  (u'WN', 6179544.0, 9),
#  (u'UA', 7705144.0, 9),
#  (u'AA', 14938066.0, 9),
#  (u'DL', 15741731.0, 9)]

# %%
# %%sql
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup = 10
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'EV', 0.0, 10),
#  (u'F9', 277476.0, 10),
#  (u'NK', 2308462.0, 10),
#  (u'HA', 3423027.0, 10),
#  (u'WN', 4798617.0, 10),
#  (u'VX', 5965932.0, 10),
#  (u'DL', 10017000.0, 10),
#  (u'B6', 11595220.0, 10),
#  (u'AS', 15019104.0, 10),
#  (u'AA', 21890538.0, 10),
#  (u'UA', 28099901.0, 10)]

# %%
# %%sql
#
# SELECT Reporting_Airline as Aerolineas, SUM(AirTime) as TiempoEnAire, DistanceGroup
# FROM ontime
# WHERE DistanceGroup =11
# GROUP BY Reporting_Airline
# ORDER BY TiempoEnAire ASC
# Out:
#  * sqlite:///proyecto1.db
# Done.
# [(u'NK', 89809.0, 11),
#  (u'WN', 183230.0, 11),
#  (u'VX', 4490336.0, 11),
#  (u'HA', 6740616.0, 11),
#  (u'B6', 10242042.0, 11),
#  (u'DL', 12075061.0, 11),
#  (u'AS', 13684600.0, 11),
#  (u'AA', 17107835.0, 11),
#  (u'UA', 20506917.0, 11)]
